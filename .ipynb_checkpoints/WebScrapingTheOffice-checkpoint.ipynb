# %% [markdown]
# # Web Scraping and Data Wrangling with The Office
#
# What does this demonstrate?
# 1. web scraping.
# 2. data wrangling.
# 3. regular expressions.
# 4. descriptive analysis.
#
# TODO:
# 1. Running total of character speeches to show importance over time.
# 2. Compare writers.
# 3. ?
#
# <https://www.officequotes.net>

# %%
from pathlib import Path
import re
from urllib.parse import urljoin

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def scrape_episode_urls(home_page=r"https://www.officequotes.net"):
    
    r = requests.get(home_page)
    soup = BeautifulSoup(r.text)
    episode_paths = [
        a.get("href")
        for a in soup.find(id="sidebar-left").find_all("a")
        if re.match(r"/no\d+-\d+.html", a.get("href"))
    ]
    
    episode_urls = map(lambda path: urljoin(home_page, path), episode_paths)

    return episode_urls
    
# Map returns a generator. Converting to a list during development.
episode_urls_list = [e for e in scrape_episode_urls()]

# %%
episode_urls_list
# Out:
# ['https://www.officequotes.net/no1-01.html',
#  'https://www.officequotes.net/no1-02.html',
#  'https://www.officequotes.net/no1-03.html',
#  'https://www.officequotes.net/no1-04.html',
#  'https://www.officequotes.net/no1-05.html',
#  'https://www.officequotes.net/no1-06.html',
#  'https://www.officequotes.net/no2-01.html',
#  'https://www.officequotes.net/no2-02.html',
#  'https://www.officequotes.net/no2-03.html',
#  'https://www.officequotes.net/no2-04.html',
#  'https://www.officequotes.net/no2-05.html',
#  'https://www.officequotes.net/no2-06.html',
#  'https://www.officequotes.net/no2-07.html',
#  'https://www.officequotes.net/no2-08.html',
#  'https://www.officequotes.net/no2-09.html',
#  'https://www.officequotes.net/no2-10.html',
#  'https://www.officequotes.net/no2-11.html',
#  'https://www.officequotes.net/no2-12.html',
#  'https://www.officequotes.net/no2-13.html',
#  'https://www.officequotes.net/no2-14.html',
#  'https://www.officequotes.net/no2-15.html',
#  'https://www.officequotes.net/no2-16.html',
#  'https://www.officequotes.net/no2-17.html',
#  'https://www.officequotes.net/no2-18.html',
#  'https://www.officequotes.net/no2-19.html',
#  'https://www.officequotes.net/no2-20.html',
#  'https://www.officequotes.net/no2-21.html',
#  'https://www.officequotes.net/no2-22.html',
#  'https://www.officequotes.net/no3-01.html',
#  'https://www.officequotes.net/no3-02.html',
#  'https://www.officequotes.net/no3-03.html',
#  'https://www.officequotes.net/no3-04.html',
#  'https://www.officequotes.net/no3-05.html',
#  'https://www.officequotes.net/no3-06.html',
#  'https://www.officequotes.net/no3-07.html',
#  'https://www.officequotes.net/no3-08.html',
#  'https://www.officequotes.net/no3-09.html',
#  'https://www.officequotes.net/no3-10.html',
#  'https://www.officequotes.net/no3-11.html',
#  'https://www.officequotes.net/no3-12.html',
#  'https://www.officequotes.net/no3-13.html',
#  'https://www.officequotes.net/no3-14.html',
#  'https://www.officequotes.net/no3-15.html',
#  'https://www.officequotes.net/no3-16.html',
#  'https://www.officequotes.net/no3-17.html',
#  'https://www.officequotes.net/no3-18.html',
#  'https://www.officequotes.net/no3-19.html',
#  'https://www.officequotes.net/no3-20.html',
#  'https://www.officequotes.net/no3-21.html',
#  'https://www.officequotes.net/no3-22.html',
#  'https://www.officequotes.net/no3-23.html',
#  'https://www.officequotes.net/no4-01.html',
#  'https://www.officequotes.net/no4-02.html',
#  'https://www.officequotes.net/no4-03.html',
#  'https://www.officequotes.net/no4-04.html',
#  'https://www.officequotes.net/no4-05.html',
#  'https://www.officequotes.net/no4-06.html',
#  'https://www.officequotes.net/no4-07.html',
#  'https://www.officequotes.net/no4-08.html',
#  'https://www.officequotes.net/no4-09.html',
#  'https://www.officequotes.net/no4-10.html',
#  'https://www.officequotes.net/no4-11.html',
#  'https://www.officequotes.net/no4-12.html',
#  'https://www.officequotes.net/no4-13.html',
#  'https://www.officequotes.net/no4-14.html',
#  'https://www.officequotes.net/no5-01.html',
#  'https://www.officequotes.net/no5-02.html',
#  'https://www.officequotes.net/no5-03.html',
#  'https://www.officequotes.net/no5-04.html',
#  'https://www.officequotes.net/no5-05.html',
#  'https://www.officequotes.net/no5-06.html',
#  'https://www.officequotes.net/no5-07.html',
#  'https://www.officequotes.net/no5-08.html',
#  'https://www.officequotes.net/no5-09.html',
#  'https://www.officequotes.net/no5-10.html',
#  'https://www.officequotes.net/no5-11.html',
#  'https://www.officequotes.net/no5-12.html',
#  'https://www.officequotes.net/no5-13.html',
#  'https://www.officequotes.net/no5-14.html',
#  'https://www.officequotes.net/no5-15.html',
#  'https://www.officequotes.net/no5-16.html',
#  'https://www.officequotes.net/no5-17.html',
#  'https://www.officequotes.net/no5-18.html',
#  'https://www.officequotes.net/no5-19.html',
#  'https://www.officequotes.net/no5-20.html',
#  'https://www.officequotes.net/no5-21.html',
#  'https://www.officequotes.net/no5-22.html',
#  'https://www.officequotes.net/no5-23.html',
#  'https://www.officequotes.net/no5-24.html',
#  'https://www.officequotes.net/no5-25.html',
#  'https://www.officequotes.net/no5-26.html',
#  'https://www.officequotes.net/no6-01.html',
#  'https://www.officequotes.net/no6-02.html',
#  'https://www.officequotes.net/no6-03.html',
#  'https://www.officequotes.net/no6-04.html',
#  'https://www.officequotes.net/no6-05.html',
#  'https://www.officequotes.net/no6-06.html',
#  'https://www.officequotes.net/no6-07.html',
#  'https://www.officequotes.net/no6-08.html',
#  'https://www.officequotes.net/no6-09.html',
#  'https://www.officequotes.net/no6-10.html',
#  'https://www.officequotes.net/no6-11.html',
#  'https://www.officequotes.net/no6-12.html',
#  'https://www.officequotes.net/no6-13.html',
#  'https://www.officequotes.net/no6-14.html',
#  'https://www.officequotes.net/no6-15.html',
#  'https://www.officequotes.net/no6-16.html',
#  'https://www.officequotes.net/no6-17.html',
#  'https://www.officequotes.net/no6-18.html',
#  'https://www.officequotes.net/no6-19.html',
#  'https://www.officequotes.net/no6-20.html',
#  'https://www.officequotes.net/no6-21.html',
#  'https://www.officequotes.net/no6-22.html',
#  'https://www.officequotes.net/no6-23.html',
#  'https://www.officequotes.net/no6-24.html',
#  'https://www.officequotes.net/no7-01.html',
#  'https://www.officequotes.net/no7-02.html',
#  'https://www.officequotes.net/no7-03.html',
#  'https://www.officequotes.net/no7-04.html',
#  'https://www.officequotes.net/no7-05.html',
#  'https://www.officequotes.net/no7-06.html',
#  'https://www.officequotes.net/no7-07.html',
#  'https://www.officequotes.net/no7-08.html',
#  'https://www.officequotes.net/no7-09.html',
#  'https://www.officequotes.net/no7-10.html',
#  'https://www.officequotes.net/no7-11.html',
#  'https://www.officequotes.net/no7-12.html',
#  'https://www.officequotes.net/no7-13.html',
#  'https://www.officequotes.net/no7-14.html',
#  'https://www.officequotes.net/no7-15.html',
#  'https://www.officequotes.net/no7-16.html',
#  'https://www.officequotes.net/no7-17.html',
#  'https://www.officequotes.net/no7-18.html',
#  'https://www.officequotes.net/no7-19.html',
#  'https://www.officequotes.net/no7-20.html',
#  'https://www.officequotes.net/no7-21.html',
#  'https://www.officequotes.net/no7-22.html',
#  'https://www.officequotes.net/no7-23.html',
#  'https://www.officequotes.net/no7-24.html',
#  'https://www.officequotes.net/no8-01.html',
#  'https://www.officequotes.net/no8-02.html',
#  'https://www.officequotes.net/no8-03.html',
#  'https://www.officequotes.net/no8-04.html',
#  'https://www.officequotes.net/no8-05.html',
#  'https://www.officequotes.net/no8-06.html',
#  'https://www.officequotes.net/no8-07.html',
#  'https://www.officequotes.net/no8-08.html',
#  'https://www.officequotes.net/no8-09.html',
#  'https://www.officequotes.net/no8-10.html',
#  'https://www.officequotes.net/no8-11.html',
#  'https://www.officequotes.net/no8-12.html',
#  'https://www.officequotes.net/no8-13.html',
#  'https://www.officequotes.net/no8-14.html',
#  'https://www.officequotes.net/no8-15.html',
#  'https://www.officequotes.net/no8-16.html',
#  'https://www.officequotes.net/no8-17.html',
#  'https://www.officequotes.net/no8-18.html',
#  'https://www.officequotes.net/no8-19.html',
#  'https://www.officequotes.net/no8-20.html',
#  'https://www.officequotes.net/no8-21.html',
#  'https://www.officequotes.net/no8-22.html',
#  'https://www.officequotes.net/no8-23.html',
#  'https://www.officequotes.net/no8-24.html',
#  'https://www.officequotes.net/no9-01.html',
#  'https://www.officequotes.net/no9-02.html',
#  'https://www.officequotes.net/no9-03.html',
#  'https://www.officequotes.net/no9-04.html',
#  'https://www.officequotes.net/no9-05.html',
#  'https://www.officequotes.net/no9-06.html',
#  'https://www.officequotes.net/no9-07.html',
#  'https://www.officequotes.net/no9-08.html',
#  'https://www.officequotes.net/no9-09.html',
#  'https://www.officequotes.net/no9-10.html',
#  'https://www.officequotes.net/no9-11.html',
#  'https://www.officequotes.net/no9-12.html',
#  'https://www.officequotes.net/no9-13.html',
#  'https://www.officequotes.net/no9-14.html',
#  'https://www.officequotes.net/no9-15.html',
#  'https://www.officequotes.net/no9-16.html',
#  'https://www.officequotes.net/no9-17.html',
#  'https://www.officequotes.net/no9-18.html',
#  'https://www.officequotes.net/no9-19.html',
#  'https://www.officequotes.net/no9-20.html',
#  'https://www.officequotes.net/no9-21.html',
#  'https://www.officequotes.net/no9-22.html',
#  'https://www.officequotes.net/no9-23.html']

# %%
# Extract some metadata for the episode.
episode_url = episode_urls_list[0]

episode_page = BeautifulSoup(requests.get(episode_url).text)

# %%
def _extract_episode_metadata(episode_page):
    """Scrape the episode's metadata from the page source.

    Args:
        episode_page (str): The page source for the episode. Best retrieved using BeautifulSoup.

    Returns:
        dict: A dictionary of the episode's metadata: Season, Episode Number, Title, Writing Credit, and Directing Credit.
    """
    p = re.compile(
        r'Season (?P<Season>\d) - Episode (?P<Episode>\d+)\n"(?P<Title>.*)"\n.*Written by (?P<WrittenBy>.*)\n.*Directed by (?P<Director>.*)\n'
    )
    s = re.search(p, episode_page.find("main").text)
    
    return s.groupdict()

# %%
extract_episode_metadata(episode_page)
# Out:
# {'Season': '1',
#  'Episode': '01',
#  'Title': 'Pilot',
#  'WrittenBy': 'Greg Daniels, Ricky Gervais, and Stephen Merchant',
#  'Director': 'Ken Kwapis'}

# %%
def extract_script(episode_page, include_deleted_scenes=False):
    """Extract the script from the episode's page.

    Args:
        episode_page (str): The page source for the episode. Best retrieved using BeautifulSoup.
        include_deleted_scenes (bool): Include deleted scenes? Defaults to False.

    Returns:
        DataFrame: Each row is a scene from the episode.
    """

    episode_metadata = _extract_episode_metadata(episode_page)
    
    scenes = enumerate(
        [
            str.strip(scene.text)
            for scene in episode_page.find("main").find_all("div", class_="quote")
        ]
    )
    df = pd.DataFrame.from_records(scenes, columns=["SceneNumber", "Dialogue"]).assign(
        IsDeletedScene=lambda df: df.Dialogue.str.match(r"Deleted Scene"), **episode_metadata
    )

    if include_deleted_scenes == False:
          df = df.query("~IsDeletedScene")
          
    return df

# %%
episode_df = extract_script(episode_page)

# %%
episode_df
# Out:
#     SceneNumber                                           Dialogue  \
# 0             0  Michael: All right Jim. Your quarterlies look ...
# 1             1  Michael: [on the phone] Yes, I'd like to speak...
# 2             2  Michael: I've, uh, I've been at Dunder Mifflin...
# 3             3  Michael: People say I am the best boss. They g...
# 4             4  Dwight: [singing] Shall I play for you? Pa rum...
# 5             5  Jim: My job is to speak to clients on the phon...
# 6             6  Michael: Whassup!\nJim: Whassup! I still love ...
# 7             7  Jan: [on her cell phone] Just before lunch. Th...
# 8             8  Michael: Corporate really doesn't really inter...
# 9             9  Jan: Alright, was there anything you wanted to...
# 10           10  Michael:  Question. How long do we have to... ...
# 11           11  Phyllis: So what does downsizing actually mean...
# 12           12  Oscar: You guys better update your resumes jus...
# 13           13  Angela: I bet it's gonna be me. Probably gonna...
# 14           14  Pam: I have an important question for you.\nJi...
# 15           15  Michael: Am I going to tell them? No, I am not...
# 16           16  Michael: Hey.\nRyan: Hey.\nPam: This is Mr. Sc...
# 17           17  Pam: I don't think it would be the worst thing...
# 18           18  Jim: Sure. Mr. Davis, let me call you right ba...
# 19           19  Dwight: Downsizing? I have no problem with tha...
# 20           20  Pam: You just still have these messages from y...
# 21           21  Michael: I think I'm a role model here. I thin...
# 22           22  Michael: People I respect, heroes of mine, wou...
# 23           23  Michael: Now I know there's some rumors out th...
# 24           24  Ryan: I heard they might be closing this branc...
# 25           25  Oscar: Yeah but Michael, what if they downsize...
# 26           26  Jim: If I left, what would I do with all this ...
# 27           27  Pam: Jim said mixed berries? Well, yeah, he's ...
# 28           28  Michael: Watch out for this guy. Dwight Schrut...
# 29           29  Dwight: Damn it! Jim!\nMichael: OK. Hold on, h...
# 30           30  Dwight: It's OK here, but people sometimes tak...
# 31           31  Michael: What is that?\nDwight: That is my sta...
# 32           32  Jim: Do you like going out at the end of the w...
# 33           33  Pam: Roy's my fiance. We've been engaged about...
# 34           34  Pam: Do you mind if I go out for a drink with ...
# 35           35  Jim: Do I think I'll be invited to the wedding...
# 36           36  Michael: So have you felt the vibe yet? We wor...
# 37           37  Michael: What is the most important thing for ...
# 38           38  Pam: Hey.\nJim: Hey.\nJim: How are things?\nPa...
#
#     IsDeletedScene Season Episode  Title  \
# 0            False      1      01  Pilot
# 1            False      1      01  Pilot
# 2            False      1      01  Pilot
# 3            False      1      01  Pilot
# 4            False      1      01  Pilot
# 5            False      1      01  Pilot
# 6            False      1      01  Pilot
# 7            False      1      01  Pilot
# 8            False      1      01  Pilot
# 9            False      1      01  Pilot
# 10           False      1      01  Pilot
# 11           False      1      01  Pilot
# 12           False      1      01  Pilot
# 13           False      1      01  Pilot
# 14           False      1      01  Pilot
# 15           False      1      01  Pilot
# 16           False      1      01  Pilot
# 17           False      1      01  Pilot
# 18           False      1      01  Pilot
# 19           False      1      01  Pilot
# 20           False      1      01  Pilot
# 21           False      1      01  Pilot
# 22           False      1      01  Pilot
# 23           False      1      01  Pilot
# 24           False      1      01  Pilot
# 25           False      1      01  Pilot
# 26           False      1      01  Pilot
# 27           False      1      01  Pilot
# 28           False      1      01  Pilot
# 29           False      1      01  Pilot
# 30           False      1      01  Pilot
# 31           False      1      01  Pilot
# 32           False      1      01  Pilot
# 33           False      1      01  Pilot
# 34           False      1      01  Pilot
# 35           False      1      01  Pilot
# 36           False      1      01  Pilot
# 37           False      1      01  Pilot
# 38           False      1      01  Pilot
#
#                                             WrittenBy    Director
# 0   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 1   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 2   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 3   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 4   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 5   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 6   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 7   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 8   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 9   Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 10  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 11  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 12  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 13  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 14  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 15  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 16  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 17  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 18  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 19  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 20  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 21  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 22  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 23  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 24  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 25  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 26  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 27  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 28  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 29  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 30  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 31  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 32  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 33  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 34  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 35  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 36  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 37  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis
# 38  Greg Daniels, Ricky Gervais, and Stephen Merchant  Ken Kwapis

# %%
def _convert_dialogue_to_cued_speeches(dialogue_string):
    """Helper function to pair the character cue with his speech in the dialogue.


    Args:
        dialogue_string (str): The complete dialogue of the scene with its character cues.

    Returns:
        list: A list of paired character cues and speeches.
    """
    p = re.compile(r"(?P<Character>[\w ]+):")
    lines = [str.strip(line) for line in p.split(dialogue_string) if line != r""]
    pair_player_and_line = zip(lines[::2], lines[1::2])
    return list(pair_player_and_line)

# %%
def character_speeches(episode_df):
    """Breakout individual speeches for each character from within the dialogue.

    Args:
        episode_df (DataFrame): DataFrame of the episode's script.

    Returns:
        DataFrame: The provided dataframe with dialogue exploded to cues and speeches.
    """
    df = (
        episode_df.assign(Lines=lambda x: x.Dialogue.apply(_convert_dialogue_to_cued_speeches))
        .explode("Lines")
        .reset_index()
        .assign(
            Character=lambda x: x.Lines.apply(pd.Series)[0],
            Speech=lambda x: x.Lines.apply(pd.Series)[1],
        )
    )
    return df

# %%
episode_df = extract_script(episode_page).pipe(character_speeches)

# %% [markdown]
# episode_df

# %%
episode_df.Speech.iloc[-1]
# Out:
# 'Yeah, definitely. You too. Enjoy it. [looks at camera] You know what, just come here.'

# %% [markdown]
# Let's turn these steps into a function that we can use in a list comprehension to make dataframes we can concatenate together.

# %%
episode_df.Character.value_counts()
# Out:
# Character
# Michael        81
# Pam            41
# Jim            36
# Dwight         29
# Jan            12
# Ryan            8
# Stanley         5
# Roy             5
# Todd Packer     3
# Oscar           3
# Phyllis         2
# Michel          1
# Angela          1
# Kevin           1
# Man             1
# Name: count, dtype: int64

# %%
# script.groupby(['SceneNumber', 'Character']).size()
episode_df.groupby("SceneNumber")["Character"].transform("nunique")
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 224    2
# 225    2
# 226    2
# 227    2
# 228    2
# Name: Character, Length: 229, dtype: int64
